# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/qubvel/segmentation_models.pytorch/blob/main/examples/cars%20segmentation%20(camvid).ipynb)

# %% [markdown]
# # Install package

# %%
# %%capture
# !pip install segmentation-models-pytorch lightning    albumentations

# %% [markdown]
# # Loading data
# For this example we will use images that were masked by a group of students at Pennsylvania State University.
#
# All images have 640 pixels height and 640 pixels width.

# %%
# %%capture
# # Download Data
# !git clone https://github.com/alexgkendall/SegNet-Tutorial ./data

# %%
import os
import cv2

import torch
import numpy as np
import albumentations as A
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset
from torch.optim import lr_scheduler
import segmentation_models_pytorch as smp
import pytorch_lightning as pl

# %%
DATA_DIR = './data/CamVid/'

x_train_dir = os.path.join(DATA_DIR, 'Train Set')
y_train_dir = os.path.join(DATA_DIR, 'Train Mask Set')

x_valid_dir = os.path.join(DATA_DIR, 'Val Set')
y_valid_dir = os.path.join(DATA_DIR, 'Val Mask Set')

x_test_dir = os.path.join(DATA_DIR, 'Test Set')
y_test_dir = os.path.join(DATA_DIR, 'Test Mask Set')

# %% [markdown]
# # Dataloader
# Writing helper class for data extraction, tranformation and preprocessing
# https://pytorch.org/docs/stable/data

# %%
class Dataset(BaseDataset):
    """CamVid Dataset. Read images, apply augmentation transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
            
    """
    
    CLASSES = []
    for x in range(256):
        if x == 0:
            CLASSES.append("notpv")
        elif x == 255:
            CLASSES.append("pv")
        else:
            CLASSES.append(x)
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
    ):
        self.ids = os.listdir(images_dir)
        self.mask_ids = os.listdir(masks_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, mask_id) for mask_id in self.mask_ids]
        print(self.images_fps)
        print(self.masks_fps)
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
    
    def __getitem__(self, i):
        # Read imgs
        image = cv2.imread(self.images_fps[i])
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # Check for an error with the files (img and mask)
        if image is None:
            raise ValueError(f"Image not found or unable to load: {self.images_fps[i]}")
        if mask is None:
            raise ValueError(f"Mask not found or unable to load: {self.masks_fps[i]}")
        
        # Resize imgs
        image, mask = cv2.resize(image, (640, 640)), cv2.resize(mask, (640, 640))
        
        # Convert to numpy array
        image = np.asarray(image)
        mask = np.asarray(mask)
        
        # extract certain classes from mask (e.g. pv)
        masks = [(mask == v) for v in self.class_values] # FIXME
        mask = np.stack(masks, axis=-1).astype('float') # FIXME
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        return image.transpose(2, 0, 1), mask.transpose(2, 0, 1)
        
    def __len__(self):
        return len(self.ids)

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if name == 'image':
            plt.imshow(image.transpose(1, 2, 0))
        else:
            plt.imshow(image)
    plt.show()

# %%
dataset = Dataset(x_train_dir, y_train_dir, classes=['pv'])
# get some sample
image, mask = dataset[0]

# Print Test
print(np.max(image))
print(np.shape(image))
print("=====")
print(np.max(mask))
print(np.shape(mask))
#

visualize(image=image, cars_mask=mask.squeeze(),)
# Out:
# ['./data/CamVid/Train Set\\037197_img_7_4.png', './data/CamVid/Train Set\\037197_img_7_5.png', './data/CamVid/Train Set\\037197_img_7_6.png', './data/CamVid/Train Set\\037197_img_7_7.png', './data/CamVid/Train Set\\037205_img_0_0.png', './data/CamVid/Train Set\\037205_img_0_1.png', './data/CamVid/Train Set\\037205_img_0_2.png', './data/CamVid/Train Set\\037205_img_0_3.png', './data/CamVid/Train Set\\037205_img_0_4.png', './data/CamVid/Train Set\\037205_img_0_5.png', './data/CamVid/Train Set\\037205_img_0_6.png', './data/CamVid/Train Set\\037205_img_0_7.png', './data/CamVid/Train Set\\037205_img_1_0.png', './data/CamVid/Train Set\\037205_img_1_1.png', './data/CamVid/Train Set\\037205_img_1_2.png', './data/CamVid/Train Set\\037205_img_1_3.png', './data/CamVid/Train Set\\037205_img_1_4.png', './data/CamVid/Train Set\\037205_img_1_5.png', './data/CamVid/Train Set\\037205_img_1_6.png', './data/CamVid/Train Set\\037205_img_1_7.png', './data/CamVid/Train Set\\037205_img_2_0.png', './data/CamVid/Train Set\\037205_img_2_1.png', './data/CamVid/Train Set\\037205_img_2_2.png', './data/CamVid/Train Set\\037205_img_2_3.png', './data/CamVid/Train Set\\037205_img_2_4.png', './data/CamVid/Train Set\\037205_img_2_5.png', './data/CamVid/Train Set\\037205_img_2_6.png', './data/CamVid/Train Set\\037205_img_2_7.png', './data/CamVid/Train Set\\037205_img_3_0.png', './data/CamVid/Train Set\\037205_img_3_1.png', './data/CamVid/Train Set\\037205_img_3_2.png', './data/CamVid/Train Set\\037205_img_3_3.png', './data/CamVid/Train Set\\037205_img_3_4.png', './data/CamVid/Train Set\\037205_img_3_5.png', './data/CamVid/Train Set\\037205_img_3_6.png', './data/CamVid/Train Set\\037205_img_3_7.png', './data/CamVid/Train Set\\037205_img_4_0.png', './data/CamVid/Train Set\\037205_img_4_1.png', './data/CamVid/Train Set\\037205_img_4_2.png', './data/CamVid/Train Set\\037205_img_4_3.png', './data/CamVid/Train Set\\037205_img_4_4.png', './data/CamVid/Train Set\\037205_img_4_5.png', './data/CamVid/Train Set\\037197_img_0_0.png', './data/CamVid/Train Set\\037197_img_0_1.png', './data/CamVid/Train Set\\037182_img_4_6.png', './data/CamVid/Train Set\\037182_img_4_7.png', './data/CamVid/Train Set\\037182_img_5_0.png', './data/CamVid/Train Set\\037182_img_5_1.png', './data/CamVid/Train Set\\037182_img_5_2.png', './data/CamVid/Train Set\\037182_img_5_3.png', './data/CamVid/Train Set\\037182_img_5_4.png', './data/CamVid/Train Set\\037182_img_5_5.png', './data/CamVid/Train Set\\037182_img_5_6.png', './data/CamVid/Train Set\\037182_img_5_7.png', './data/CamVid/Train Set\\037182_img_6_0.png', './data/CamVid/Train Set\\037182_img_6_1.png', './data/CamVid/Train Set\\037182_img_6_2.png', './data/CamVid/Train Set\\037182_img_6_3.png', './data/CamVid/Train Set\\037182_img_6_4.png', './data/CamVid/Train Set\\037182_img_6_5.png', './data/CamVid/Train Set\\037182_img_6_6.png', './data/CamVid/Train Set\\037182_img_6_7.png', './data/CamVid/Train Set\\037182_img_7_0.png', './data/CamVid/Train Set\\037182_img_7_1.png', './data/CamVid/Train Set\\037182_img_7_2.png', './data/CamVid/Train Set\\037182_img_7_3.png', './data/CamVid/Train Set\\037182_img_7_4.png', './data/CamVid/Train Set\\037182_img_7_5.png', './data/CamVid/Train Set\\037182_img_7_6.png', './data/CamVid/Train Set\\037182_img_7_7.png', './data/CamVid/Train Set\\037195_img_0_0.png', './data/CamVid/Train Set\\037195_img_0_1.png', './data/CamVid/Train Set\\037195_img_0_2.png', './data/CamVid/Train Set\\037195_img_0_3.png', './data/CamVid/Train Set\\037195_img_0_4.png', './data/CamVid/Train Set\\037195_img_0_5.png', './data/CamVid/Train Set\\037195_img_0_6.png', './data/CamVid/Train Set\\037195_img_0_7.png', './data/CamVid/Train Set\\037195_img_1_0.png', './data/CamVid/Train Set\\037195_img_1_1.png', './data/CamVid/Train Set\\037195_img_1_2.png', './data/CamVid/Train Set\\037195_img_1_3.png', './data/CamVid/Train Set\\037195_img_1_4.png', './data/CamVid/Train Set\\037195_img_1_5.png', './data/CamVid/Train Set\\037195_img_1_6.png', './d ...
# ['./data/CamVid/Train Mask Set\\037197_mask_7_2.png', './data/CamVid/Train Mask Set\\037197_mask_7_3.png', './data/CamVid/Train Mask Set\\037197_mask_7_4.png', './data/CamVid/Train Mask Set\\037197_mask_7_5.png', './data/CamVid/Train Mask Set\\037197_mask_7_6.png', './data/CamVid/Train Mask Set\\037197_mask_7_7.png', './data/CamVid/Train Mask Set\\037205_mask_0_0.png', './data/CamVid/Train Mask Set\\037205_mask_0_1.png', './data/CamVid/Train Mask Set\\037205_mask_0_2.png', './data/CamVid/Train Mask Set\\037205_mask_0_3.png', './data/CamVid/Train Mask Set\\037205_mask_0_4.png', './data/CamVid/Train Mask Set\\037205_mask_0_5.png', './data/CamVid/Train Mask Set\\037205_mask_0_6.png', './data/CamVid/Train Mask Set\\037205_mask_0_7.png', './data/CamVid/Train Mask Set\\037205_mask_1_0.png', './data/CamVid/Train Mask Set\\037205_mask_1_1.png', './data/CamVid/Train Mask Set\\037205_mask_1_2.png', './data/CamVid/Train Mask Set\\037205_mask_1_3.png', './data/CamVid/Train Mask Set\\037205_mask_1_4.png', './data/CamVid/Train Mask Set\\037205_mask_1_5.png', './data/CamVid/Train Mask Set\\037205_mask_1_6.png', './data/CamVid/Train Mask Set\\037205_mask_1_7.png', './data/CamVid/Train Mask Set\\037205_mask_2_0.png', './data/CamVid/Train Mask Set\\037205_mask_2_1.png', './data/CamVid/Train Mask Set\\037205_mask_2_2.png', './data/CamVid/Train Mask Set\\037205_mask_2_3.png', './data/CamVid/Train Mask Set\\037205_mask_2_4.png', './data/CamVid/Train Mask Set\\037205_mask_2_5.png', './data/CamVid/Train Mask Set\\037205_mask_2_6.png', './data/CamVid/Train Mask Set\\037205_mask_2_7.png', './data/CamVid/Train Mask Set\\037205_mask_3_0.png', './data/CamVid/Train Mask Set\\037205_mask_3_1.png', './data/CamVid/Train Mask Set\\037205_mask_3_2.png', './data/CamVid/Train Mask Set\\037205_mask_3_3.png', './data/CamVid/Train Mask Set\\037205_mask_3_4.png', './data/CamVid/Train Mask Set\\037205_mask_3_5.png', './data/CamVid/Train Mask Set\\037205_mask_3_6.png', './data/CamVid/Train Mask Set\\037205_mask_3_7.png', './data/CamVid/Train Mask Set\\037205_mask_4_0.png', './data/CamVid/Train Mask Set\\037205_mask_4_1.png', './data/CamVid/Train Mask Set\\037205_mask_4_2.png', './data/CamVid/Train Mask Set\\037205_mask_4_3.png', './data/CamVid/Train Mask Set\\037205_mask_4_4.png', './data/CamVid/Train Mask Set\\037205_mask_4_5.png', './data/CamVid/Train Mask Set\\037182_mask_4_6.png', './data/CamVid/Train Mask Set\\037182_mask_4_7.png', './data/CamVid/Train Mask Set\\037182_mask_5_0.png', './data/CamVid/Train Mask Set\\037182_mask_5_1.png', './data/CamVid/Train Mask Set\\037182_mask_5_2.png', './data/CamVid/Train Mask Set\\037182_mask_5_3.png', './data/CamVid/Train Mask Set\\037182_mask_5_4.png', './data/CamVid/Train Mask Set\\037182_mask_5_5.png', './data/CamVid/Train Mask Set\\037182_mask_5_6.png', './data/CamVid/Train Mask Set\\037182_mask_5_7.png', './data/CamVid/Train Mask Set\\037182_mask_6_0.png', './data/CamVid/Train Mask Set\\037182_mask_6_1.png', './data/CamVid/Train Mask Set\\037182_mask_6_2.png', './data/CamVid/Train Mask Set\\037182_mask_6_3.png', './data/CamVid/Train Mask Set\\037182_mask_6_4.png', './data/CamVid/Train Mask Set\\037182_mask_6_5.png', './data/CamVid/Train Mask Set\\037182_mask_6_6.png', './data/CamVid/Train Mask Set\\037182_mask_6_7.png', './data/CamVid/Train Mask Set\\037182_mask_7_0.png', './data/CamVid/Train Mask Set\\037182_mask_7_1.png', './data/CamVid/Train Mask Set\\037182_mask_7_2.png', './data/CamVid/Train Mask Set\\037182_mask_7_3.png', './data/CamVid/Train Mask Set\\037182_mask_7_4.png', './data/CamVid/Train Mask Set\\037182_mask_7_5.png', './data/CamVid/Train Mask Set\\037182_mask_7_6.png', './data/CamVid/Train Mask Set\\037182_mask_7_7.png', './data/CamVid/Train Mask Set\\037195_mask_0_0.png', './data/CamVid/Train Mask Set\\037195_mask_0_1.png', './data/CamVid/Train Mask Set\\037195_mask_0_2.png', './data/CamVid/Train Mask Set\\037195_mask_0_3.png', './data/CamVid/Train Mask Set\\037195_mask_0_4.png', './data/CamVid/Train Mas ...
# 255
# (3, 640, 640)
# =====
# 0.0
# (1, 640, 640)

# %% [markdown]
# # Augmentations
# Data augmentation is a powerful technique to increase the amount of your data and prevent model overfitting.
# If you not familiar with such trick read some of these articles:
#
#  - [The Effectiveness of Data Augmentation in Image Classification using Deep Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
#  - [Data Augmentation | How to use Deep Learning when you have Limited Data](https://medium.com/nanonets/how-to-use-deep-learning-when-you-have-limited-data-part-2-data-augmentation-c26971dc8ced)
#  - [Data Augmentation Experimentation](https://towardsdatascience.com/data-augmentation-experimentation-3e274504f04b)
#
# Since our dataset is very small we will apply a large number of different augmentations:
#
#  - horizontal flip
#  - affine transforms
#  - perspective transforms
#  - brightness/contrast/colors manipulations
#  - image bluring and sharpening
#  - gaussian noise
#  - random crops
#
# All this transforms can be easily applied with [**Albumentations**](https://github.com/albu/albumentations/) - fast augmentation library. For detailed explanation of image transformations you can look at [**kaggle salt segmentation exmaple**](https://github.com/albu/albumentations/blob/master/notebooks/example_kaggle_salt.ipynb) provided by [**Albumentations**](https://github.com/albu/albumentations/) authors.

# %%
# training set images augmentation
def get_training_augmentation():
    train_transform = [
        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=320, min_width=320, always_apply=True),
        A.RandomCrop(height=320, width=320, always_apply=True),

        A.GaussNoise(p=0.2),
        A.Perspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightnessContrast(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.Sharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),
        A.OneOf(
            [
                A.RandomBrightnessContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return A.Compose(train_transform)

def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(640, 640),
    ]
    return A.Compose(test_transform)

# %%
# Visualize resulted augmented images and masks
augmented_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    classes=['pv'],
)

# same image with different random transforms
for i in range(2):
    image, mask = augmented_dataset[1]
    visualize(image=image, mask=mask.squeeze())
# Out:
# ['./data/CamVid/Train Set\\037197_img_7_4.png', './data/CamVid/Train Set\\037197_img_7_5.png', './data/CamVid/Train Set\\037197_img_7_6.png', './data/CamVid/Train Set\\037197_img_7_7.png', './data/CamVid/Train Set\\037205_img_0_0.png', './data/CamVid/Train Set\\037205_img_0_1.png', './data/CamVid/Train Set\\037205_img_0_2.png', './data/CamVid/Train Set\\037205_img_0_3.png', './data/CamVid/Train Set\\037205_img_0_4.png', './data/CamVid/Train Set\\037205_img_0_5.png', './data/CamVid/Train Set\\037205_img_0_6.png', './data/CamVid/Train Set\\037205_img_0_7.png', './data/CamVid/Train Set\\037205_img_1_0.png', './data/CamVid/Train Set\\037205_img_1_1.png', './data/CamVid/Train Set\\037205_img_1_2.png', './data/CamVid/Train Set\\037205_img_1_3.png', './data/CamVid/Train Set\\037205_img_1_4.png', './data/CamVid/Train Set\\037205_img_1_5.png', './data/CamVid/Train Set\\037205_img_1_6.png', './data/CamVid/Train Set\\037205_img_1_7.png', './data/CamVid/Train Set\\037205_img_2_0.png', './data/CamVid/Train Set\\037205_img_2_1.png', './data/CamVid/Train Set\\037205_img_2_2.png', './data/CamVid/Train Set\\037205_img_2_3.png', './data/CamVid/Train Set\\037205_img_2_4.png', './data/CamVid/Train Set\\037205_img_2_5.png', './data/CamVid/Train Set\\037205_img_2_6.png', './data/CamVid/Train Set\\037205_img_2_7.png', './data/CamVid/Train Set\\037205_img_3_0.png', './data/CamVid/Train Set\\037205_img_3_1.png', './data/CamVid/Train Set\\037205_img_3_2.png', './data/CamVid/Train Set\\037205_img_3_3.png', './data/CamVid/Train Set\\037205_img_3_4.png', './data/CamVid/Train Set\\037205_img_3_5.png', './data/CamVid/Train Set\\037205_img_3_6.png', './data/CamVid/Train Set\\037205_img_3_7.png', './data/CamVid/Train Set\\037205_img_4_0.png', './data/CamVid/Train Set\\037205_img_4_1.png', './data/CamVid/Train Set\\037205_img_4_2.png', './data/CamVid/Train Set\\037205_img_4_3.png', './data/CamVid/Train Set\\037205_img_4_4.png', './data/CamVid/Train Set\\037205_img_4_5.png', './data/CamVid/Train Set\\037197_img_0_0.png', './data/CamVid/Train Set\\037197_img_0_1.png', './data/CamVid/Train Set\\037182_img_4_6.png', './data/CamVid/Train Set\\037182_img_4_7.png', './data/CamVid/Train Set\\037182_img_5_0.png', './data/CamVid/Train Set\\037182_img_5_1.png', './data/CamVid/Train Set\\037182_img_5_2.png', './data/CamVid/Train Set\\037182_img_5_3.png', './data/CamVid/Train Set\\037182_img_5_4.png', './data/CamVid/Train Set\\037182_img_5_5.png', './data/CamVid/Train Set\\037182_img_5_6.png', './data/CamVid/Train Set\\037182_img_5_7.png', './data/CamVid/Train Set\\037182_img_6_0.png', './data/CamVid/Train Set\\037182_img_6_1.png', './data/CamVid/Train Set\\037182_img_6_2.png', './data/CamVid/Train Set\\037182_img_6_3.png', './data/CamVid/Train Set\\037182_img_6_4.png', './data/CamVid/Train Set\\037182_img_6_5.png', './data/CamVid/Train Set\\037182_img_6_6.png', './data/CamVid/Train Set\\037182_img_6_7.png', './data/CamVid/Train Set\\037182_img_7_0.png', './data/CamVid/Train Set\\037182_img_7_1.png', './data/CamVid/Train Set\\037182_img_7_2.png', './data/CamVid/Train Set\\037182_img_7_3.png', './data/CamVid/Train Set\\037182_img_7_4.png', './data/CamVid/Train Set\\037182_img_7_5.png', './data/CamVid/Train Set\\037182_img_7_6.png', './data/CamVid/Train Set\\037182_img_7_7.png', './data/CamVid/Train Set\\037195_img_0_0.png', './data/CamVid/Train Set\\037195_img_0_1.png', './data/CamVid/Train Set\\037195_img_0_2.png', './data/CamVid/Train Set\\037195_img_0_3.png', './data/CamVid/Train Set\\037195_img_0_4.png', './data/CamVid/Train Set\\037195_img_0_5.png', './data/CamVid/Train Set\\037195_img_0_6.png', './data/CamVid/Train Set\\037195_img_0_7.png', './data/CamVid/Train Set\\037195_img_1_0.png', './data/CamVid/Train Set\\037195_img_1_1.png', './data/CamVid/Train Set\\037195_img_1_2.png', './data/CamVid/Train Set\\037195_img_1_3.png', './data/CamVid/Train Set\\037195_img_1_4.png', './data/CamVid/Train Set\\037195_img_1_5.png', './data/CamVid/Train Set\\037195_img_1_6.png', './d ...
# ['./data/CamVid/Train Mask Set\\037197_mask_7_2.png', './data/CamVid/Train Mask Set\\037197_mask_7_3.png', './data/CamVid/Train Mask Set\\037197_mask_7_4.png', './data/CamVid/Train Mask Set\\037197_mask_7_5.png', './data/CamVid/Train Mask Set\\037197_mask_7_6.png', './data/CamVid/Train Mask Set\\037197_mask_7_7.png', './data/CamVid/Train Mask Set\\037205_mask_0_0.png', './data/CamVid/Train Mask Set\\037205_mask_0_1.png', './data/CamVid/Train Mask Set\\037205_mask_0_2.png', './data/CamVid/Train Mask Set\\037205_mask_0_3.png', './data/CamVid/Train Mask Set\\037205_mask_0_4.png', './data/CamVid/Train Mask Set\\037205_mask_0_5.png', './data/CamVid/Train Mask Set\\037205_mask_0_6.png', './data/CamVid/Train Mask Set\\037205_mask_0_7.png', './data/CamVid/Train Mask Set\\037205_mask_1_0.png', './data/CamVid/Train Mask Set\\037205_mask_1_1.png', './data/CamVid/Train Mask Set\\037205_mask_1_2.png', './data/CamVid/Train Mask Set\\037205_mask_1_3.png', './data/CamVid/Train Mask Set\\037205_mask_1_4.png', './data/CamVid/Train Mask Set\\037205_mask_1_5.png', './data/CamVid/Train Mask Set\\037205_mask_1_6.png', './data/CamVid/Train Mask Set\\037205_mask_1_7.png', './data/CamVid/Train Mask Set\\037205_mask_2_0.png', './data/CamVid/Train Mask Set\\037205_mask_2_1.png', './data/CamVid/Train Mask Set\\037205_mask_2_2.png', './data/CamVid/Train Mask Set\\037205_mask_2_3.png', './data/CamVid/Train Mask Set\\037205_mask_2_4.png', './data/CamVid/Train Mask Set\\037205_mask_2_5.png', './data/CamVid/Train Mask Set\\037205_mask_2_6.png', './data/CamVid/Train Mask Set\\037205_mask_2_7.png', './data/CamVid/Train Mask Set\\037205_mask_3_0.png', './data/CamVid/Train Mask Set\\037205_mask_3_1.png', './data/CamVid/Train Mask Set\\037205_mask_3_2.png', './data/CamVid/Train Mask Set\\037205_mask_3_3.png', './data/CamVid/Train Mask Set\\037205_mask_3_4.png', './data/CamVid/Train Mask Set\\037205_mask_3_5.png', './data/CamVid/Train Mask Set\\037205_mask_3_6.png', './data/CamVid/Train Mask Set\\037205_mask_3_7.png', './data/CamVid/Train Mask Set\\037205_mask_4_0.png', './data/CamVid/Train Mask Set\\037205_mask_4_1.png', './data/CamVid/Train Mask Set\\037205_mask_4_2.png', './data/CamVid/Train Mask Set\\037205_mask_4_3.png', './data/CamVid/Train Mask Set\\037205_mask_4_4.png', './data/CamVid/Train Mask Set\\037205_mask_4_5.png', './data/CamVid/Train Mask Set\\037182_mask_4_6.png', './data/CamVid/Train Mask Set\\037182_mask_4_7.png', './data/CamVid/Train Mask Set\\037182_mask_5_0.png', './data/CamVid/Train Mask Set\\037182_mask_5_1.png', './data/CamVid/Train Mask Set\\037182_mask_5_2.png', './data/CamVid/Train Mask Set\\037182_mask_5_3.png', './data/CamVid/Train Mask Set\\037182_mask_5_4.png', './data/CamVid/Train Mask Set\\037182_mask_5_5.png', './data/CamVid/Train Mask Set\\037182_mask_5_6.png', './data/CamVid/Train Mask Set\\037182_mask_5_7.png', './data/CamVid/Train Mask Set\\037182_mask_6_0.png', './data/CamVid/Train Mask Set\\037182_mask_6_1.png', './data/CamVid/Train Mask Set\\037182_mask_6_2.png', './data/CamVid/Train Mask Set\\037182_mask_6_3.png', './data/CamVid/Train Mask Set\\037182_mask_6_4.png', './data/CamVid/Train Mask Set\\037182_mask_6_5.png', './data/CamVid/Train Mask Set\\037182_mask_6_6.png', './data/CamVid/Train Mask Set\\037182_mask_6_7.png', './data/CamVid/Train Mask Set\\037182_mask_7_0.png', './data/CamVid/Train Mask Set\\037182_mask_7_1.png', './data/CamVid/Train Mask Set\\037182_mask_7_2.png', './data/CamVid/Train Mask Set\\037182_mask_7_3.png', './data/CamVid/Train Mask Set\\037182_mask_7_4.png', './data/CamVid/Train Mask Set\\037182_mask_7_5.png', './data/CamVid/Train Mask Set\\037182_mask_7_6.png', './data/CamVid/Train Mask Set\\037182_mask_7_7.png', './data/CamVid/Train Mask Set\\037195_mask_0_0.png', './data/CamVid/Train Mask Set\\037195_mask_0_1.png', './data/CamVid/Train Mask Set\\037195_mask_0_2.png', './data/CamVid/Train Mask Set\\037195_mask_0_3.png', './data/CamVid/Train Mask Set\\037195_mask_0_4.png', './data/CamVid/Train Mas ...

# %%
CLASSES = ['pv']

train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    classes=CLASSES,
)

valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    augmentation=get_validation_augmentation(), 
    classes=CLASSES,
)

test_dataset = Dataset(
    x_test_dir,
    y_test_dir,
    augmentation=get_validation_augmentation(), 
    classes=CLASSES,
)

train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=0)
valid_loader = DataLoader(valid_dataset, batch_size=2, shuffle=False, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False, num_workers=0)
# Out:
# ['./data/CamVid/Train Set\\037197_img_7_4.png', './data/CamVid/Train Set\\037197_img_7_5.png', './data/CamVid/Train Set\\037197_img_7_6.png', './data/CamVid/Train Set\\037197_img_7_7.png', './data/CamVid/Train Set\\037205_img_0_0.png', './data/CamVid/Train Set\\037205_img_0_1.png', './data/CamVid/Train Set\\037205_img_0_2.png', './data/CamVid/Train Set\\037205_img_0_3.png', './data/CamVid/Train Set\\037205_img_0_4.png', './data/CamVid/Train Set\\037205_img_0_5.png', './data/CamVid/Train Set\\037205_img_0_6.png', './data/CamVid/Train Set\\037205_img_0_7.png', './data/CamVid/Train Set\\037205_img_1_0.png', './data/CamVid/Train Set\\037205_img_1_1.png', './data/CamVid/Train Set\\037205_img_1_2.png', './data/CamVid/Train Set\\037205_img_1_3.png', './data/CamVid/Train Set\\037205_img_1_4.png', './data/CamVid/Train Set\\037205_img_1_5.png', './data/CamVid/Train Set\\037205_img_1_6.png', './data/CamVid/Train Set\\037205_img_1_7.png', './data/CamVid/Train Set\\037205_img_2_0.png', './data/CamVid/Train Set\\037205_img_2_1.png', './data/CamVid/Train Set\\037205_img_2_2.png', './data/CamVid/Train Set\\037205_img_2_3.png', './data/CamVid/Train Set\\037205_img_2_4.png', './data/CamVid/Train Set\\037205_img_2_5.png', './data/CamVid/Train Set\\037205_img_2_6.png', './data/CamVid/Train Set\\037205_img_2_7.png', './data/CamVid/Train Set\\037205_img_3_0.png', './data/CamVid/Train Set\\037205_img_3_1.png', './data/CamVid/Train Set\\037205_img_3_2.png', './data/CamVid/Train Set\\037205_img_3_3.png', './data/CamVid/Train Set\\037205_img_3_4.png', './data/CamVid/Train Set\\037205_img_3_5.png', './data/CamVid/Train Set\\037205_img_3_6.png', './data/CamVid/Train Set\\037205_img_3_7.png', './data/CamVid/Train Set\\037205_img_4_0.png', './data/CamVid/Train Set\\037205_img_4_1.png', './data/CamVid/Train Set\\037205_img_4_2.png', './data/CamVid/Train Set\\037205_img_4_3.png', './data/CamVid/Train Set\\037205_img_4_4.png', './data/CamVid/Train Set\\037205_img_4_5.png', './data/CamVid/Train Set\\037197_img_0_0.png', './data/CamVid/Train Set\\037197_img_0_1.png', './data/CamVid/Train Set\\037182_img_4_6.png', './data/CamVid/Train Set\\037182_img_4_7.png', './data/CamVid/Train Set\\037182_img_5_0.png', './data/CamVid/Train Set\\037182_img_5_1.png', './data/CamVid/Train Set\\037182_img_5_2.png', './data/CamVid/Train Set\\037182_img_5_3.png', './data/CamVid/Train Set\\037182_img_5_4.png', './data/CamVid/Train Set\\037182_img_5_5.png', './data/CamVid/Train Set\\037182_img_5_6.png', './data/CamVid/Train Set\\037182_img_5_7.png', './data/CamVid/Train Set\\037182_img_6_0.png', './data/CamVid/Train Set\\037182_img_6_1.png', './data/CamVid/Train Set\\037182_img_6_2.png', './data/CamVid/Train Set\\037182_img_6_3.png', './data/CamVid/Train Set\\037182_img_6_4.png', './data/CamVid/Train Set\\037182_img_6_5.png', './data/CamVid/Train Set\\037182_img_6_6.png', './data/CamVid/Train Set\\037182_img_6_7.png', './data/CamVid/Train Set\\037182_img_7_0.png', './data/CamVid/Train Set\\037182_img_7_1.png', './data/CamVid/Train Set\\037182_img_7_2.png', './data/CamVid/Train Set\\037182_img_7_3.png', './data/CamVid/Train Set\\037182_img_7_4.png', './data/CamVid/Train Set\\037182_img_7_5.png', './data/CamVid/Train Set\\037182_img_7_6.png', './data/CamVid/Train Set\\037182_img_7_7.png', './data/CamVid/Train Set\\037195_img_0_0.png', './data/CamVid/Train Set\\037195_img_0_1.png', './data/CamVid/Train Set\\037195_img_0_2.png', './data/CamVid/Train Set\\037195_img_0_3.png', './data/CamVid/Train Set\\037195_img_0_4.png', './data/CamVid/Train Set\\037195_img_0_5.png', './data/CamVid/Train Set\\037195_img_0_6.png', './data/CamVid/Train Set\\037195_img_0_7.png', './data/CamVid/Train Set\\037195_img_1_0.png', './data/CamVid/Train Set\\037195_img_1_1.png', './data/CamVid/Train Set\\037195_img_1_2.png', './data/CamVid/Train Set\\037195_img_1_3.png', './data/CamVid/Train Set\\037195_img_1_4.png', './data/CamVid/Train Set\\037195_img_1_5.png', './data/CamVid/Train Set\\037195_img_1_6.png', './d ...
# ['./data/CamVid/Train Mask Set\\037197_mask_7_2.png', './data/CamVid/Train Mask Set\\037197_mask_7_3.png', './data/CamVid/Train Mask Set\\037197_mask_7_4.png', './data/CamVid/Train Mask Set\\037197_mask_7_5.png', './data/CamVid/Train Mask Set\\037197_mask_7_6.png', './data/CamVid/Train Mask Set\\037197_mask_7_7.png', './data/CamVid/Train Mask Set\\037205_mask_0_0.png', './data/CamVid/Train Mask Set\\037205_mask_0_1.png', './data/CamVid/Train Mask Set\\037205_mask_0_2.png', './data/CamVid/Train Mask Set\\037205_mask_0_3.png', './data/CamVid/Train Mask Set\\037205_mask_0_4.png', './data/CamVid/Train Mask Set\\037205_mask_0_5.png', './data/CamVid/Train Mask Set\\037205_mask_0_6.png', './data/CamVid/Train Mask Set\\037205_mask_0_7.png', './data/CamVid/Train Mask Set\\037205_mask_1_0.png', './data/CamVid/Train Mask Set\\037205_mask_1_1.png', './data/CamVid/Train Mask Set\\037205_mask_1_2.png', './data/CamVid/Train Mask Set\\037205_mask_1_3.png', './data/CamVid/Train Mask Set\\037205_mask_1_4.png', './data/CamVid/Train Mask Set\\037205_mask_1_5.png', './data/CamVid/Train Mask Set\\037205_mask_1_6.png', './data/CamVid/Train Mask Set\\037205_mask_1_7.png', './data/CamVid/Train Mask Set\\037205_mask_2_0.png', './data/CamVid/Train Mask Set\\037205_mask_2_1.png', './data/CamVid/Train Mask Set\\037205_mask_2_2.png', './data/CamVid/Train Mask Set\\037205_mask_2_3.png', './data/CamVid/Train Mask Set\\037205_mask_2_4.png', './data/CamVid/Train Mask Set\\037205_mask_2_5.png', './data/CamVid/Train Mask Set\\037205_mask_2_6.png', './data/CamVid/Train Mask Set\\037205_mask_2_7.png', './data/CamVid/Train Mask Set\\037205_mask_3_0.png', './data/CamVid/Train Mask Set\\037205_mask_3_1.png', './data/CamVid/Train Mask Set\\037205_mask_3_2.png', './data/CamVid/Train Mask Set\\037205_mask_3_3.png', './data/CamVid/Train Mask Set\\037205_mask_3_4.png', './data/CamVid/Train Mask Set\\037205_mask_3_5.png', './data/CamVid/Train Mask Set\\037205_mask_3_6.png', './data/CamVid/Train Mask Set\\037205_mask_3_7.png', './data/CamVid/Train Mask Set\\037205_mask_4_0.png', './data/CamVid/Train Mask Set\\037205_mask_4_1.png', './data/CamVid/Train Mask Set\\037205_mask_4_2.png', './data/CamVid/Train Mask Set\\037205_mask_4_3.png', './data/CamVid/Train Mask Set\\037205_mask_4_4.png', './data/CamVid/Train Mask Set\\037205_mask_4_5.png', './data/CamVid/Train Mask Set\\037182_mask_4_6.png', './data/CamVid/Train Mask Set\\037182_mask_4_7.png', './data/CamVid/Train Mask Set\\037182_mask_5_0.png', './data/CamVid/Train Mask Set\\037182_mask_5_1.png', './data/CamVid/Train Mask Set\\037182_mask_5_2.png', './data/CamVid/Train Mask Set\\037182_mask_5_3.png', './data/CamVid/Train Mask Set\\037182_mask_5_4.png', './data/CamVid/Train Mask Set\\037182_mask_5_5.png', './data/CamVid/Train Mask Set\\037182_mask_5_6.png', './data/CamVid/Train Mask Set\\037182_mask_5_7.png', './data/CamVid/Train Mask Set\\037182_mask_6_0.png', './data/CamVid/Train Mask Set\\037182_mask_6_1.png', './data/CamVid/Train Mask Set\\037182_mask_6_2.png', './data/CamVid/Train Mask Set\\037182_mask_6_3.png', './data/CamVid/Train Mask Set\\037182_mask_6_4.png', './data/CamVid/Train Mask Set\\037182_mask_6_5.png', './data/CamVid/Train Mask Set\\037182_mask_6_6.png', './data/CamVid/Train Mask Set\\037182_mask_6_7.png', './data/CamVid/Train Mask Set\\037182_mask_7_0.png', './data/CamVid/Train Mask Set\\037182_mask_7_1.png', './data/CamVid/Train Mask Set\\037182_mask_7_2.png', './data/CamVid/Train Mask Set\\037182_mask_7_3.png', './data/CamVid/Train Mask Set\\037182_mask_7_4.png', './data/CamVid/Train Mask Set\\037182_mask_7_5.png', './data/CamVid/Train Mask Set\\037182_mask_7_6.png', './data/CamVid/Train Mask Set\\037182_mask_7_7.png', './data/CamVid/Train Mask Set\\037195_mask_0_0.png', './data/CamVid/Train Mask Set\\037195_mask_0_1.png', './data/CamVid/Train Mask Set\\037195_mask_0_2.png', './data/CamVid/Train Mask Set\\037195_mask_0_3.png', './data/CamVid/Train Mask Set\\037195_mask_0_4.png', './data/CamVid/Train Mas ...
# ['./data/CamVid/Val Set\\037205_img_4_6.png', './data/CamVid/Val Set\\037205_img_4_7.png', './data/CamVid/Val Set\\037205_img_5_0.png', './data/CamVid/Val Set\\037205_img_5_1.png', './data/CamVid/Val Set\\037205_img_5_2.png', './data/CamVid/Val Set\\037205_img_5_3.png', './data/CamVid/Val Set\\037205_img_5_4.png', './data/CamVid/Val Set\\037205_img_5_5.png', './data/CamVid/Val Set\\037205_img_5_6.png', './data/CamVid/Val Set\\037205_img_5_7.png', './data/CamVid/Val Set\\037205_img_6_0.png', './data/CamVid/Val Set\\037205_img_6_1.png', './data/CamVid/Val Set\\037205_img_6_2.png', './data/CamVid/Val Set\\037205_img_6_3.png', './data/CamVid/Val Set\\037205_img_6_4.png', './data/CamVid/Val Set\\037205_img_6_5.png', './data/CamVid/Val Set\\037205_img_6_6.png', './data/CamVid/Val Set\\037205_img_6_7.png', './data/CamVid/Val Set\\037205_img_7_0.png', './data/CamVid/Val Set\\037205_img_7_1.png', './data/CamVid/Val Set\\037205_img_7_2.png', './data/CamVid/Val Set\\037205_img_7_3.png', './data/CamVid/Val Set\\037205_img_7_4.png', './data/CamVid/Val Set\\037205_img_7_5.png', './data/CamVid/Val Set\\037205_img_7_6.png', './data/CamVid/Val Set\\037205_img_7_7.png']
# ['./data/CamVid/Val Mask Set\\037197_mask_1_0.png', './data/CamVid/Val Mask Set\\037197_mask_1_1.png', './data/CamVid/Val Mask Set\\037197_mask_1_2.png', './data/CamVid/Val Mask Set\\037197_mask_1_3.png', './data/CamVid/Val Mask Set\\037197_mask_1_4.png', './data/CamVid/Val Mask Set\\037197_mask_1_5.png', './data/CamVid/Val Mask Set\\037197_mask_1_6.png', './data/CamVid/Val Mask Set\\037197_mask_1_7.png', './data/CamVid/Val Mask Set\\037197_mask_2_0.png', './data/CamVid/Val Mask Set\\037197_mask_2_1.png', './data/CamVid/Val Mask Set\\037197_mask_2_2.png', './data/CamVid/Val Mask Set\\037197_mask_2_3.png', './data/CamVid/Val Mask Set\\037197_mask_2_4.png', './data/CamVid/Val Mask Set\\037197_mask_2_5.png', './data/CamVid/Val Mask Set\\037197_mask_2_6.png', './data/CamVid/Val Mask Set\\037197_mask_2_7.png', './data/CamVid/Val Mask Set\\037197_mask_3_0.png', './data/CamVid/Val Mask Set\\037197_mask_3_1.png', './data/CamVid/Val Mask Set\\037197_mask_3_2.png', './data/CamVid/Val Mask Set\\037197_mask_3_3.png', './data/CamVid/Val Mask Set\\037197_mask_3_4.png', './data/CamVid/Val Mask Set\\037197_mask_3_5.png', './data/CamVid/Val Mask Set\\037197_mask_3_6.png', './data/CamVid/Val Mask Set\\037197_mask_3_7.png', './data/CamVid/Val Mask Set\\037197_mask_4_0.png', './data/CamVid/Val Mask Set\\037197_mask_4_1.png', './data/CamVid/Val Mask Set\\037197_mask_4_2.png', './data/CamVid/Val Mask Set\\037197_mask_4_3.png', './data/CamVid/Val Mask Set\\037197_mask_4_4.png', './data/CamVid/Val Mask Set\\037197_mask_4_5.png', './data/CamVid/Val Mask Set\\037197_mask_4_6.png', './data/CamVid/Val Mask Set\\037197_mask_4_7.png', './data/CamVid/Val Mask Set\\037197_mask_5_0.png', './data/CamVid/Val Mask Set\\037197_mask_5_1.png', './data/CamVid/Val Mask Set\\037197_mask_5_2.png', './data/CamVid/Val Mask Set\\037197_mask_5_3.png', './data/CamVid/Val Mask Set\\037197_mask_5_4.png', './data/CamVid/Val Mask Set\\037197_mask_5_5.png', './data/CamVid/Val Mask Set\\037197_mask_5_6.png', './data/CamVid/Val Mask Set\\037197_mask_5_7.png', './data/CamVid/Val Mask Set\\037197_mask_6_0.png', './data/CamVid/Val Mask Set\\037197_mask_6_1.png', './data/CamVid/Val Mask Set\\037197_mask_6_2.png', './data/CamVid/Val Mask Set\\037197_mask_6_3.png', './data/CamVid/Val Mask Set\\037197_mask_6_4.png', './data/CamVid/Val Mask Set\\037197_mask_6_5.png', './data/CamVid/Val Mask Set\\037197_mask_6_6.png', './data/CamVid/Val Mask Set\\037197_mask_6_7.png', './data/CamVid/Val Mask Set\\037197_mask_7_0.png', './data/CamVid/Val Mask Set\\037197_mask_7_1.png', './data/CamVid/Val Mask Set\\037197_mask_7_2.png', './data/CamVid/Val Mask Set\\037197_mask_7_3.png', './data/CamVid/Val Mask Set\\037197_mask_7_4.png', './data/CamVid/Val Mask Set\\037197_mask_7_5.png', './data/CamVid/Val Mask Set\\037197_mask_7_6.png', './data/CamVid/Val Mask Set\\037197_mask_7_7.png', './data/CamVid/Val Mask Set\\037205_mask_0_0.png', './data/CamVid/Val Mask Set\\037205_mask_0_1.png', './data/CamVid/Val Mask Set\\037205_mask_0_2.png', './data/CamVid/Val Mask Set\\037205_mask_0_3.png', './data/CamVid/Val Mask Set\\037205_mask_0_4.png', './data/CamVid/Val Mask Set\\037205_mask_0_5.png', './data/CamVid/Val Mask Set\\037205_mask_0_6.png', './data/CamVid/Val Mask Set\\037205_mask_0_7.png', './data/CamVid/Val Mask Set\\037205_mask_1_0.png', './data/CamVid/Val Mask Set\\037205_mask_1_1.png', './data/CamVid/Val Mask Set\\037205_mask_1_2.png', './data/CamVid/Val Mask Set\\037205_mask_1_3.png', './data/CamVid/Val Mask Set\\037205_mask_1_4.png', './data/CamVid/Val Mask Set\\037205_mask_1_5.png', './data/CamVid/Val Mask Set\\037205_mask_1_6.png', './data/CamVid/Val Mask Set\\037205_mask_1_7.png', './data/CamVid/Val Mask Set\\037205_mask_2_0.png', './data/CamVid/Val Mask Set\\037205_mask_2_1.png', './data/CamVid/Val Mask Set\\037205_mask_2_2.png', './data/CamVid/Val Mask Set\\037205_mask_2_3.png', './data/CamVid/Val Mask Set\\037205_mask_2_4.png', './data/CamVid/Val Mask Set\\037205_mask_2_5.png', './data/CamVid/Val Ma ...
# ['./data/CamVid/Test Set\\037182_img_0_0.png', './data/CamVid/Test Set\\037182_img_0_1.png', './data/CamVid/Test Set\\037182_img_0_2.png', './data/CamVid/Test Set\\037182_img_0_3.png', './data/CamVid/Test Set\\037182_img_0_4.png', './data/CamVid/Test Set\\037182_img_0_5.png', './data/CamVid/Test Set\\037182_img_0_6.png', './data/CamVid/Test Set\\037182_img_0_7.png', './data/CamVid/Test Set\\037182_img_1_0.png', './data/CamVid/Test Set\\037182_img_1_1.png', './data/CamVid/Test Set\\037182_img_1_2.png', './data/CamVid/Test Set\\037182_img_1_3.png', './data/CamVid/Test Set\\037182_img_1_4.png', './data/CamVid/Test Set\\037182_img_1_5.png', './data/CamVid/Test Set\\037182_img_1_6.png', './data/CamVid/Test Set\\037182_img_1_7.png', './data/CamVid/Test Set\\037182_img_2_0.png', './data/CamVid/Test Set\\037182_img_2_1.png', './data/CamVid/Test Set\\037182_img_2_2.png', './data/CamVid/Test Set\\037182_img_2_3.png', './data/CamVid/Test Set\\037182_img_2_4.png', './data/CamVid/Test Set\\037182_img_2_5.png', './data/CamVid/Test Set\\037182_img_2_6.png', './data/CamVid/Test Set\\037182_img_2_7.png', './data/CamVid/Test Set\\037182_img_3_0.png', './data/CamVid/Test Set\\037182_img_3_1.png', './data/CamVid/Test Set\\037182_img_3_2.png', './data/CamVid/Test Set\\037182_img_3_3.png', './data/CamVid/Test Set\\037182_img_3_4.png', './data/CamVid/Test Set\\037182_img_3_5.png', './data/CamVid/Test Set\\037182_img_3_6.png', './data/CamVid/Test Set\\037182_img_3_7.png', './data/CamVid/Test Set\\037182_img_4_0.png', './data/CamVid/Test Set\\037182_img_4_1.png', './data/CamVid/Test Set\\037182_img_4_2.png', './data/CamVid/Test Set\\037182_img_4_3.png', './data/CamVid/Test Set\\037182_img_4_4.png', './data/CamVid/Test Set\\037182_img_4_5.png']
# ['./data/CamVid/Test Mask Set\\037182_mask_0_0.png', './data/CamVid/Test Mask Set\\037182_mask_0_1.png', './data/CamVid/Test Mask Set\\037182_mask_0_2.png', './data/CamVid/Test Mask Set\\037182_mask_0_3.png', './data/CamVid/Test Mask Set\\037182_mask_0_4.png', './data/CamVid/Test Mask Set\\037182_mask_0_5.png', './data/CamVid/Test Mask Set\\037182_mask_0_6.png', './data/CamVid/Test Mask Set\\037182_mask_0_7.png', './data/CamVid/Test Mask Set\\037182_mask_1_0.png', './data/CamVid/Test Mask Set\\037182_mask_1_1.png', './data/CamVid/Test Mask Set\\037182_mask_1_2.png', './data/CamVid/Test Mask Set\\037182_mask_1_3.png', './data/CamVid/Test Mask Set\\037182_mask_1_4.png', './data/CamVid/Test Mask Set\\037182_mask_1_5.png', './data/CamVid/Test Mask Set\\037182_mask_1_6.png', './data/CamVid/Test Mask Set\\037182_mask_1_7.png', './data/CamVid/Test Mask Set\\037182_mask_2_0.png', './data/CamVid/Test Mask Set\\037182_mask_2_1.png', './data/CamVid/Test Mask Set\\037182_mask_2_2.png', './data/CamVid/Test Mask Set\\037182_mask_2_3.png', './data/CamVid/Test Mask Set\\037182_mask_2_4.png', './data/CamVid/Test Mask Set\\037182_mask_2_5.png', './data/CamVid/Test Mask Set\\037182_mask_2_6.png', './data/CamVid/Test Mask Set\\037182_mask_2_7.png', './data/CamVid/Test Mask Set\\037182_mask_3_0.png', './data/CamVid/Test Mask Set\\037182_mask_3_1.png', './data/CamVid/Test Mask Set\\037182_mask_3_2.png', './data/CamVid/Test Mask Set\\037182_mask_3_3.png', './data/CamVid/Test Mask Set\\037182_mask_3_4.png', './data/CamVid/Test Mask Set\\037182_mask_3_5.png', './data/CamVid/Test Mask Set\\037182_mask_3_6.png', './data/CamVid/Test Mask Set\\037182_mask_3_7.png', './data/CamVid/Test Mask Set\\037182_mask_4_0.png', './data/CamVid/Test Mask Set\\037182_mask_4_1.png', './data/CamVid/Test Mask Set\\037182_mask_4_2.png', './data/CamVid/Test Mask Set\\037182_mask_4_3.png', './data/CamVid/Test Mask Set\\037182_mask_4_4.png', './data/CamVid/Test Mask Set\\037182_mask_4_5.png']

# %% [markdown]
# # Create model and train

# %%
# Some training hyperparameters
EPOCHS = 2
T_MAX = EPOCHS * len(train_loader)
OUT_CLASSES = 1

# %%
class CamVidModel(pl.LightningModule):

    def __init__(self, arch, encoder_name, in_channels, out_classes, **kwargs):
        super().__init__()
        self.model = smp.create_model(
            arch, encoder_name=encoder_name, in_channels=in_channels, classes=out_classes, **kwargs
        )
        # preprocessing parameteres for image
        params = smp.encoders.get_preprocessing_params(encoder_name)
        self.register_buffer("std", torch.tensor(params["std"]).view(1, 3, 1, 1))
        self.register_buffer("mean", torch.tensor(params["mean"]).view(1, 3, 1, 1))
        
        # for image segmentation dice loss could be the best first choice
        self.loss_fn = smp.losses.DiceLoss(smp.losses.BINARY_MODE, from_logits=True)
        
        # initialize step metics
        self.training_step_outputs = []
        self.validation_step_outputs = []
        self.test_step_outputs = []
        

    def forward(self, image):
        # normalize image here
        image = (image - self.mean) / self.std
        mask = self.model(image)
        return mask

    def shared_step(self, batch, stage):
        image, mask = batch
        
        # Shape of the image should be (batch_size, num_channels, height, width)
        # if you work with grayscale images, expand channels dim to have [batch_size, 1, height, width]
        assert image.ndim == 4
        
        # Check that image dimensions are divisible by 32, 
        # encoder and decoder connected by `skip connections` and usually encoder have 5 stages of 
        # downsampling by factor 2 (2 ^ 5 = 32); e.g. if we have image with shape 65x65 we will have 
        # following shapes of features in encoder and decoder: 84, 42, 21, 10, 5 -> 5, 10, 20, 40, 80
        # and we will get an error trying to concat these features
        h, w = image.shape[2:]
        assert h % 32 == 0 and w % 32 == 0
        
        assert mask.ndim == 4

        # Check that mask values in between 0 and 1, NOT 0 and 255 for binary segmentation
        assert mask.max() <= 1.0 and mask.min() >= 0
        
        logits_mask = self.forward(image)
        
        # Predicted mask contains logits, and loss_fn param `from_logits` is set to True
        loss = self.loss_fn(logits_mask, mask)
        
        # Lets compute metrics for some threshold
        # first convert mask values to probabilities, then 
        # apply thresholding
        prob_mask = logits_mask.sigmoid()
        pred_mask = (prob_mask > 0.5).float()
        
        # We will compute IoU metric by two ways
        #   1. dataset-wise
        #   2. image-wise
        # but for now we just compute true positive, false positive, false negative and
        # true negative 'pixels' for each image and class
        # these values will be aggregated in the end of an epoch
        tp, fp, fn, tn = smp.metrics.get_stats(pred_mask.long(), mask.long(), mode="binary")
        return {
            "loss": loss,
            "tp": tp,
            "fp": fp,
            "fn": fn,
            "tn": tn,
        }

    def shared_epoch_end(self, outputs, stage):
        # aggregate step metics
        tp = torch.cat([x["tp"] for x in outputs])
        fp = torch.cat([x["fp"] for x in outputs])
        fn = torch.cat([x["fn"] for x in outputs])
        tn = torch.cat([x["tn"] for x in outputs])
        
        # per image IoU means that we first calculate IoU score for each image 
        # and then compute mean over these scores
        per_image_iou = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro-imagewise")
        
        # dataset IoU means that we aggregate intersection and union over whole dataset
        # and then compute IoU score. The difference between dataset_iou and per_image_iou scores
        # in this particular case will not be much, however for dataset 
        # with "empty" images (images without target class) a large gap could be observed. 
        # Empty images influence a lot on per_image_iou and much less on dataset_iou.
        dataset_iou = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro")
        metrics = {
            f"{stage}_per_image_iou": per_image_iou,
            f"{stage}_dataset_iou": dataset_iou,
        }
        
        self.log_dict(metrics, prog_bar=True)

    def training_step(self, batch, batch_idx):
        train_loss_info = self.shared_step(batch, "train")
        # append the metics of each step to the
        self.training_step_outputs.append(train_loss_info)
        return train_loss_info

    def on_train_epoch_end(self):
        self.shared_epoch_end(self.training_step_outputs, "train")
        # empty set output list
        self.training_step_outputs.clear()
        return 

    def validation_step(self, batch, batch_idx):
        valid_loss_info = self.shared_step(batch, "valid")
        self.validation_step_outputs.append(valid_loss_info)
        return valid_loss_info

    def on_validation_epoch_end(self):
        self.shared_epoch_end(self.validation_step_outputs, "valid")
        self.validation_step_outputs.clear()
        return 

    def test_step(self, batch, batch_idx):
        test_loss_info = self.shared_step(batch, "test")
        self.test_step_outputs.append(test_loss_info)
        return test_loss_info

    def on_test_epoch_end(self):
        self.shared_epoch_end(self.test_step_outputs, "test")
        # empty set output list
        self.test_step_outputs.clear()
        return 

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=2e-4)
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_MAX, eta_min=1e-5)
        return {
            'optimizer': optimizer,
            'lr_scheduler': {
                'scheduler': scheduler,
                'interval': 'step',
                'frequency': 1
            }
        }
        return

# %%
model = CamVidModel("FPN", "resnext50_32x4d", in_channels=3, out_classes=OUT_CLASSES)

# %% [markdown]
# # Training

# %%
trainer = pl.Trainer(max_epochs=EPOCHS, log_every_n_steps=1)

trainer.fit(
    model, 
    train_dataloaders=train_loader, 
    val_dataloaders=valid_loader,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | model   | FPN      | 25.6 M | train
# 1 | loss_fn | DiceLoss | 0      | train
# ---------------------------------------------
# 25.6 M    Trainable params
# 0         Non-trainable params
# 25.6 M    Total params
# 102.352   Total estimated model params size (MB)
# 210       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# C:\Users\edwin\miniconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# C:\Users\edwin\miniconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.

# %% [markdown]
# # Validation and test metrics

# %%
# run validation dataset
valid_metrics = trainer.validate(model, dataloaders=valid_loader, verbose=False)
print(valid_metrics)
# Out:
# Validation: |          | 0/? [00:00<?, ?it/s]
# [{'valid_per_image_iou': 0.07692307978868484, 'valid_dataset_iou': 0.0}]

# %%
# run test dataset
test_metrics = trainer.test(model, dataloaders=test_loader, verbose=False)
print(test_metrics)
# Out:
# C:\Users\edwin\miniconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:424: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# [{'test_per_image_iou': 0.26536980271339417, 'test_dataset_iou': 0.010182363912463188}]

# %% [markdown]
# # Result visualization

# %%
images, masks = next(iter(test_loader))
with torch.no_grad():
    model.eval()
    logits = model(images)
pr_masks = logits.sigmoid()
for idx, (image, gt_mask, pr_mask) in enumerate(zip(images, masks, pr_masks)):
    # Number of samples visualized
    if idx <= 4:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy().transpose(1, 2, 0))
        plt.title("Image")
        plt.axis("off")

        plt.subplot(1, 3, 2)
        plt.imshow(gt_mask.numpy().squeeze())
        plt.title("Ground truth")
        plt.axis("off")

        plt.subplot(1, 3, 3)
        plt.imshow(pr_mask.numpy().squeeze())
        plt.title("Prediction")
        plt.axis("off")
        plt.show()
    else:
        break
